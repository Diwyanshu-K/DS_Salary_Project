# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

df= pd.read_csv('salary_data_cleaned.csv')
df.indo()
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer', 'min_salary', 'max_salary', 'avg', 'salary_mean',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'
		
## Job title and seniority 
		
##  Fix state Los Angeles 

##  Job description length 

##  Competitor count

## hourly wage to annual 

#remove new line from job title

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# mle                22
# manager            22
# director           14
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
# Fix state Los Angeles 
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# CO     11
# DC     11
# WI     10
# IN     10
# UT     10
# MO      9
# AZ      9
# AL      8
# GA      6
# MI      6
# DE      6
# KY      6
# CT      5
# IA      5
# NE      4
# OR      4
# LA      4
# NM      3
# KS      3
# MN      2
# ID      2
# SC      1
# RI      1
# Name: job_state, dtype: int64

# %%
#  Job description length 
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: desc_len, Length: 742, dtype: int64

# %%
#Competitor count
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
df['Competitors']
# Out:
# 0                                                     -1
# 1                                                     -1
# 2                                                     -1
# 3      Oak Ridge National Laboratory, National Renewa...
# 4                   Commerce Signals, Cardlytics, Yodlee
#                              ...
# 737                           Pfizer, AstraZeneca, Merck
# 738                      See Tickets, TicketWeb, Vendini
# 739                                                   -1
# 740                                                   -1
# 741                                                   -1
# Name: Competitors, Length: 742, dtype: object

# %%
#hourly wage to annual 

df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis =1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis =1)

# %%
df[df.hourly ==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n', ''))

# %%
df['company_txt']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_txt, Length: 742, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly    employer  min_salary  \
# count  742.000000   742.000000  742.000000  742.000000  742.000000
# mean     3.618868  1837.154987    0.032345    0.022911   74.719677
# std      0.801210   497.183763    0.177034    0.149721   30.980593
# min     -1.000000    -1.000000    0.000000    0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000    0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000    0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000    0.000000   91.000000
# max      5.000000  2019.000000    1.000000    1.000000  202.000000
#
#        max_salary            avg    salary_mean  same_state         age  \
# count  742.000000     742.000000     742.000000  742.000000  742.000000
# mean   128.149596   31676.125337   31676.125337    0.557951   46.591644
# std     45.220324   22172.381450   22172.381450    0.496965   53.778815
# min     16.000000     508.500000     508.500000    0.000000   -1.000000
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer', 'min_salary', 'max_salary', 'avg', 'salary_mean',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.avg_salary.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-09236f334497> in <module>
# ----> 1 df.avg_salary.hist()
#
# c:\users\diwya\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'avg_salary'

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['age','avg_salary','Rating'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-a963a0119270> in <module>
# ----> 1 df.boxplot(column = ['age','avg_salary','Rating'])
#
# c:\users\diwya\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     503         layout=layout,
#     504         return_type=return_type,
# --> 505         **kwargs,
#     506     )
#     507
#
# c:\users\diwya\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     389         layout=layout,
#     390         return_type=return_type,
# --> 391         **kwds,
#     392     )
#     393     plt.draw_if_interactive()
#
# ...

# %%
df.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
df[['age','Rating','desc_len']].corr()
# Out:
#                age    Rating  desc_len
# age       1.000000  0.021655  0.163911
# Rating    0.021655  1.000000 -0.012281
# desc_len  0.163911 -0.012281  1.000000

# %%
#Removing Average salaries.

cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','Rating','desc_len','num_comp']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state', 'python_yn', 'R_yn',
       'spark', 'aws', 'excel', 'job_simp', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 200
# graph for Headquarters: total = 198
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for company_txt: total = 343
# graph for job_state: total = 37
# graph for same_state: total = 2
# graph for python_yn: total = 2
# graph for R_yn: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simp: total = 7
# graph for seniority: total = 3

# %%
for i in df_cat[['Location','Headquarters','company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_txt: total = 20

# %%
pd.pivot_table(df, index = 'job_simp', values = 'max_salary')
# Out:
#                 max_salary
# job_simp
# analyst          85.215686
# data engineer   134.655462
# data scientist  145.247312
# director        208.214286
# manager         109.954545
# mle             162.500000
# na              113.793478

# %%
pd.pivot_table(df, index = ['job_simp','seniority'], values = 'avg_salary')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-08e38fb85056> in <module>
# ----> 1 pd.pivot_table(df, index = ['job_simp','seniority'], values = 'avg_salary')
#
# c:\users\diwya\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      86         for i in values:
#      87             if i not in data:
# ---> 88                 raise KeyError(i)
#      89
#      90         to_filter = []
#
# KeyError: 'avg_salary'

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'max_salary').sort_values('job_state', ascending = False)
# Out:
#                           max_salary
# job_state job_simp
# WI        na               68.000000
#           data scientist  141.000000
#           analyst          75.666667
# WA        na              130.000000
#           data scientist  122.470588
# ...                              ...
# AZ        analyst          71.000000
#           na              166.000000
# AL        na               57.500000
#           data engineer    86.000000
#           analyst          79.800000
#
# [114 rows x 1 columns]

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'max_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                           max_salary
# job_state job_simp
# WI        na                       4
#           data scientist           3
#           analyst                  3
# WA        na                       1
#           data scientist          17
# ...                              ...
# AZ        analyst                  1
#           na                       2
# AL        na                       2
#           data engineer            1
#           analyst                  5
#
# [114 rows x 1 columns]

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state', values = 'max_salary').sort_values('max_salary', ascending = False)
# Out:
#            max_salary
# job_state
# CA         175.058824
# UT         173.000000
# DC         168.400000
# MO         157.666667
# IL         146.133333
# NC         144.666667
# NY         143.475000
# PA         142.666667
# MA         141.766667
# WI         141.000000
# MD         135.769231
# VA         135.500000
# CO         135.333333
# NJ         132.000000
# OH         131.571429
# MI         127.250000
# TX         125.230769
# WA         122.470588
# OR         122.333333
# TN         122.000000
# FL         116.714286
# IN         106.000000
# KY         105.000000
# CT         105.000000
# GA         101.333333
# NM          93.666667
# AZ          88.000000
